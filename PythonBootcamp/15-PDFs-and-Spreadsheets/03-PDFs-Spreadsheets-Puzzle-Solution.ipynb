# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # PDFs and Spreadsheets Puzzle Exercise
#
# You will need to work with two files for this exercise and solve the following tasks:
#
# * Task One: Grab the Google Drive link from the .csv file. (Hint: Its along the diagonal).
# * Task Two: Download the PDF from the Google Drive link (we already downloaded it for you just in case you can't download from Google Drive) and find the phone number that is in the document. Note: There are different ways of formatting a phone number!

# %% [markdown]
# ## Task One: Grab the Google Drive Link from .csv File

# %%
import csv

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\thenboo\OneDrive\Documents\MSBA\ISA 514 BigData\PythonBootcamp\PythonBootcamp\15-PDFs-and-Spreadsheets

# %%
import os

print(os.path.exists('wikipedia_parks.csv'))
# Out:
# True

# %% [markdown]
# **Grab all the lines of data.**

# %%
data = open('wikipedia_parks.csv',encoding="utf-8")
csv_data = csv.reader(data)
data_lines = list(csv_data)

# %% [markdown]
# **We can see its along the diagonal, which means the values are at the index position that matches the row's number order. So the 1st letter is the 1st item in the 1st row, the 2nd letter is the 2nd item in the 2nd row, the 3rd item is the 3rd letter in the 3rd row and so on. We can use enumerate to track the row number and simply index off the data_lines.**

# %% [markdown]
# **Method One**

# %%
link_list = []
for row_num,data in enumerate(data_lines):
    link_list.append(data[row_num])

# %%
''.join(link_list)
# Out:
# 'Location39°20′41.23″N 84°16′06.99″W\ufeff / \ufeff39.3447861°N 84.2686083°W\ufeff / 39.3447861; -84.2686083OperatingMarch 31, 1973; 52 years ago (1973-03-31)Six FlagsRick Fiedler'

# %% [markdown]
# **Method Two**

# %%
link_str = ''
for row_num,data in enumerate(data_lines):
    link_str+=data[row_num]

# %%
link_str
# Out:
# 'Location39°20′41.23″N 84°16′06.99″W\ufeff / \ufeff39.3447861°N 84.2686083°W\ufeff / 39.3447861; -84.2686083OperatingMarch 31, 1973; 52 years ago (1973-03-31)Six FlagsRick Fiedler'

# %% [markdown]
# ## Task Two: Download the PDF from the Google Drive link and find the phone number that is in the document.

# %%
import pypdf

# %%
f = open('Math-Gym-December.pdf','rb')

# %%
pdf = pypdf.PdfReader(f)

# %%
len(pdf.pages)
# Out:
# 10

# %% [markdown]
# ## Phone Number Matching
#
# Lot's of ways to do this, but you had to figure out the phone number was in format ###.###.####
#
# Hint: https://stackoverflow.com/questions/4697882/how-can-i-find-all-matches-to-a-regular-expression-in-python

# %%
import re

# %%
pattern = r'\d{3}'

# %%
all_text = ''

for n in range(len(pdf.pages)):
    
    page = pdf.pages[n]
    page_text = page.extract_text()
    
    all_text = all_text+' '+page_text

# %%
for match in re.finditer(pattern,all_text):
    print(match)
# Out:
# <re.Match object; span=(888, 891), match='121'>
# <re.Match object; span=(896, 899), match='100'>
# <re.Match object; span=(904, 907), match='420'>
# <re.Match object; span=(912, 915), match='110'>
# <re.Match object; span=(920, 923), match='426'>
# <re.Match object; span=(1198, 1201), match='199'>
# <re.Match object; span=(1205, 1208), match='999'>
# <re.Match object; span=(1223, 1226), match='190'>
# <re.Match object; span=(1231, 1234), match='109'>
# <re.Match object; span=(1239, 1242), match='100'>
# <re.Match object; span=(1247, 1250), match='199'>
# <re.Match object; span=(1255, 1258), match='100'>
# <re.Match object; span=(1534, 1537), match='169'>
# <re.Match object; span=(1541, 1544), match='144'>
# <re.Match object; span=(1548, 1551), match='150'>
# <re.Match object; span=(1555, 1558), match='156'>
# <re.Match object; span=(1562, 1565), match='199'>
# <re.Match object; span=(1937, 1940), match='121'>
# <re.Match object; span=(1944, 1947), match='125'>
# <re.Match object; span=(2524, 2527), match='156'>
# <re.Match object; span=(2531, 2534), match='157'>
# <re.Match object; span=(2538, 2541), match='898'>
# <re.Match object; span=(3172, 3175), match='333'>
# <re.Match object; span=(3176, 3179), match='333'>
# <re.Match object; span=(3193, 3196), match='318'>
# <re.Match object; span=(3197, 3200), match='324'>
# <re.Match object; span=(4241, 4244), match='199'>
# <re.Match object; span=(4779, 4782), match='199'>
# <re.Match object; span=(6260, 6263), match='199'>
# <re.Match object; span=(6267, 6270), match='199'>
# <re.Match object; span=(6274, 6277), match='199'>
# <re.Match object; span=(6297, 6300), match='199'>

# %% [markdown]
# Once you know the correct pattern:

# %%
import re

# %%
pattern = r'\d{3}.\d{3}.\d{4}'

# %%
for n in range(len(pdf.pages)):
    
    page  = pdf.pages[n]
    page_text = page.extract_text()
    match = re.search(pattern,page_text)
    
    if match:
        print(match.group())

# %% [markdown]
# Great Job! Information on this phone number:
# * https://www.businessinsider.com/better-call-saul-billboard-and-phone-number-2014-7
# * https://www.reddit.com/r/betterCallSaul/comments/4awouf/heres_a_list_of_real_numbers_you_can_call_from/
